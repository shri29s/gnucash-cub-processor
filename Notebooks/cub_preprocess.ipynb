# %%
import pandas as pd
import numpy as np
import pdfplumber
import csv

# %%
def convert(pdf_path, csv_path):
    with pdfplumber.open(pdf_path) as pdf, open(csv_path, "w") as csv_file:
        writer = csv.writer(csv_file, lineterminator="\n")
        for page in pdf.pages:
            tables = page.extract_tables()
            for table in tables:
                if table:
                    for row in table:
                        writer.writerow(row)

# %%
convert("../statement_pdf.pdf", "../statement.csv")

# %%
df = pd.read_csv("../statement.csv", header=None)

# %%
df.head()
# Out:
#             0                                                  1          2  \
# 0        DATE                                        DESCRIPTION  CHEQUE NO
# 1  03/04/2025  TO ONL UPI/DR/509335780211/THE ULTI/YESB/PAYTM...        NaN
# 2  04/04/2025  TO ONL UPI/DR/546087903003/INDIAN I/SBIN/38329...        NaN
# 3  04/04/2025  TO ONL UPI/DR/546078415439/INDIAN I/SBIN/38329...        NaN
# 4  06/04/2025  TO ONL UPI/DR/546320612982/SAPTARSI/SBIN/SAPTA...        NaN
#
#        3       4          5
# 0  DEBIT  CREDIT    BALANCE
# 1  30.00     NaN  18,985.78
# 2  17.00     NaN  18,968.78
# 3  32.00     NaN  18,936.78
# 4  47.50     NaN  18,889.28

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop(0, axis=0, inplace=True)

# %%
df.head()
# Out:
#             0                                                  1    2      3  \
# 1  03/04/2025  TO ONL UPI/DR/509335780211/THE ULTI/YESB/PAYTM...  NaN  30.00
# 2  04/04/2025  TO ONL UPI/DR/546087903003/INDIAN I/SBIN/38329...  NaN  17.00
# 3  04/04/2025  TO ONL UPI/DR/546078415439/INDIAN I/SBIN/38329...  NaN  32.00
# 4  06/04/2025  TO ONL UPI/DR/546320612982/SAPTARSI/SBIN/SAPTA...  NaN  47.50
# 5  07/04/2025  BY ONL UPI/CR/509734628153/KHURSHID/NSPB/AKURS...  NaN    NaN
#
#       4          5
# 1   NaN  18,985.78
# 2   NaN  18,968.78
# 3   NaN  18,936.78
# 4   NaN  18,889.28
# 5  1.00  18,890.28

# %%
def categorize(desc: str, debit):
    desc = str(desc).upper()
    if "UPI" in desc:
        return "Expenses:UPI"
    elif "INTEREST" in desc:
        return "Income:Interest"
    elif debit:
        return "Expenses:Misc"
    else:
        return "Income:Misc"

# %%
df.drop([2, 5], axis=1, inplace=True)

# %%
df.head()
# Out:
#             0                                                  1      3     4
# 1  03/04/2025  TO ONL UPI/DR/509335780211/THE ULTI/YESB/PAYTM...  30.00   NaN
# 2  04/04/2025  TO ONL UPI/DR/546087903003/INDIAN I/SBIN/38329...  17.00   NaN
# 3  04/04/2025  TO ONL UPI/DR/546078415439/INDIAN I/SBIN/38329...  32.00   NaN
# 4  06/04/2025  TO ONL UPI/DR/546320612982/SAPTARSI/SBIN/SAPTA...  47.50   NaN
# 5  07/04/2025  BY ONL UPI/CR/509734628153/KHURSHID/NSPB/AKURS...    NaN  1.00

# %%
df.columns = ["Date", "Description", "Debit", "Credit"]

# %%
df.head()
# Out:
#          Date                                        Description  Debit Credit
# 1  03/04/2025  TO ONL UPI/DR/509335780211/THE ULTI/YESB/PAYTM...  30.00    NaN
# 2  04/04/2025  TO ONL UPI/DR/546087903003/INDIAN I/SBIN/38329...  17.00    NaN
# 3  04/04/2025  TO ONL UPI/DR/546078415439/INDIAN I/SBIN/38329...  32.00    NaN
# 4  06/04/2025  TO ONL UPI/DR/546320612982/SAPTARSI/SBIN/SAPTA...  47.50    NaN
# 5  07/04/2025  BY ONL UPI/CR/509734628153/KHURSHID/NSPB/AKURS...    NaN   1.00

# %%
df['Account'] = df.apply(lambda x: categorize(x["Description"], x["Debit"]), axis=1)

# %%
df.head()
# Out:
#          Date                                        Description  Debit  \
# 1  03/04/2025  TO ONL UPI/DR/509335780211/THE ULTI/YESB/PAYTM...  30.00
# 2  04/04/2025  TO ONL UPI/DR/546087903003/INDIAN I/SBIN/38329...  17.00
# 3  04/04/2025  TO ONL UPI/DR/546078415439/INDIAN I/SBIN/38329...  32.00
# 4  06/04/2025  TO ONL UPI/DR/546320612982/SAPTARSI/SBIN/SAPTA...  47.50
# 5  07/04/2025  BY ONL UPI/CR/509734628153/KHURSHID/NSPB/AKURS...    NaN
#
#   Credit       Account
# 1    NaN  Expenses:UPI
# 2    NaN  Expenses:UPI
# 3    NaN  Expenses:UPI
# 4    NaN  Expenses:UPI
# 5   1.00  Expenses:UPI

# %%
df["Debit"] = df['Debit'].fillna(0)
df["Credit"] = df['Credit'].fillna(0)

# %%
def currency_to_float(value):
    if isinstance(value, str):
        value = value.replace('₹', '').replace('$', '')  # Remove currency symbols
        value = value.replace(',', '')                  # Remove commas
    return float(value)

# %%
df["Debit"] = df["Debit"].apply(currency_to_float)
df["Credit"] = df["Credit"].apply(currency_to_float)

# %%
df["Amount"] = df["Credit"] - df["Debit"]

# %%
df.head()
# Out:
#          Date                                        Description  Debit  \
# 1  03/04/2025  TO ONL UPI/DR/509335780211/THE ULTI/YESB/PAYTM...   30.0
# 2  04/04/2025  TO ONL UPI/DR/546087903003/INDIAN I/SBIN/38329...   17.0
# 3  04/04/2025  TO ONL UPI/DR/546078415439/INDIAN I/SBIN/38329...   32.0
# 4  06/04/2025  TO ONL UPI/DR/546320612982/SAPTARSI/SBIN/SAPTA...   47.5
# 5  07/04/2025  BY ONL UPI/CR/509734628153/KHURSHID/NSPB/AKURS...    0.0
#
#    Credit       Account  Amount
# 1     0.0  Expenses:UPI   -30.0
# 2     0.0  Expenses:UPI   -17.0
# 3     0.0  Expenses:UPI   -32.0
# 4     0.0  Expenses:UPI   -47.5
# 5     1.0  Expenses:UPI     1.0

# %%
df = df[["Date", "Description", "Account", "Amount"]]

# %%
df.head()
# Out:
#          Date                                        Description  \
# 1  03/04/2025  TO ONL UPI/DR/509335780211/THE ULTI/YESB/PAYTM...
# 2  04/04/2025  TO ONL UPI/DR/546087903003/INDIAN I/SBIN/38329...
# 3  04/04/2025  TO ONL UPI/DR/546078415439/INDIAN I/SBIN/38329...
# 4  06/04/2025  TO ONL UPI/DR/546320612982/SAPTARSI/SBIN/SAPTA...
# 5  07/04/2025  BY ONL UPI/CR/509734628153/KHURSHID/NSPB/AKURS...
#
#         Account  Amount
# 1  Expenses:UPI   -30.0
# 2  Expenses:UPI   -17.0
# 3  Expenses:UPI   -32.0
# 4  Expenses:UPI   -47.5
# 5  Expenses:UPI     1.0

# %%
df.to_csv("statement.csv", index=False)

# %%
df[df['Date'] != "TOTAL"]
# Out:
#           Date                                        Description  \
# 1   03/04/2025  TO ONL UPI/DR/509335780211/THE ULTI/YESB/PAYTM...
# 2   04/04/2025  TO ONL UPI/DR/546087903003/INDIAN I/SBIN/38329...
# 3   04/04/2025  TO ONL UPI/DR/546078415439/INDIAN I/SBIN/38329...
# 4   06/04/2025  TO ONL UPI/DR/546320612982/SAPTARSI/SBIN/SAPTA...
# 5   07/04/2025  BY ONL UPI/CR/509734628153/KHURSHID/NSPB/AKURS...
# ..         ...                                                ...
# 67  28/06/2025  TO ONL UPI/DR/517984203840/RS AGENC/YESB/PAYTM...
# 68  29/06/2025  TO ONL UPI/DR/518086972754/MAHESH S/YESB/PAYTM...
# 69  29/06/2025  TO ONL UPI/DR/518092952923/VIJAYA K/YESB/PAYTM...
# 70  30/06/2025  BY ONL UPI/CR/503670351815/GOOGLE P/UTIB/GOOGL...
# 71  30/06/2025                           BY CREDIT INTEREST:99999
#
#             Account  Amount
# 1      Expenses:UPI   -30.0
# 2      Expenses:UPI   -17.0
# 3      Expenses:UPI   -32.0
# 4      Expenses:UPI   -47.5
# 5      Expenses:UPI     1.0
# ..              ...     ...
# 67     Expenses:UPI  -215.0
# 68     Expenses:UPI   -88.0
# 69     Expenses:UPI   -10.0
# 70     Expenses:UPI     2.0
# 71  Income:Interest   138.0
#
# [70 rows x 4 columns]

# %%
import re

def mask_desc(desc):
    return re.sub(r"\d", "x", str(desc))

# %%
df[df["Description"] == ""]
# Out:
# Empty DataFrame
# Columns: [Date, Description, Account, Amount]
# Index: []

# %%
df['Desc_masked'] = df["Description"].apply(mask_desc)

# %%
df["Desc_masked"]
# Out:
# 1     TO ONL UPI/DR/xxxxxxxxxxxx/THE ULTI/YESB/PAYTM...
# 2     TO ONL UPI/DR/xxxxxxxxxxxx/INDIAN I/SBIN/xxxxx...
# 3     TO ONL UPI/DR/xxxxxxxxxxxx/INDIAN I/SBIN/xxxxx...
# 4     TO ONL UPI/DR/xxxxxxxxxxxx/SAPTARSI/SBIN/SAPTA...
# 5     BY ONL UPI/CR/xxxxxxxxxxxx/KHURSHID/NSPB/AKURS...
#                             ...
# 68    TO ONL UPI/DR/xxxxxxxxxxxx/MAHESH S/YESB/PAYTM...
# 69    TO ONL UPI/DR/xxxxxxxxxxxx/VIJAYA K/YESB/PAYTM...
# 70    BY ONL UPI/CR/xxxxxxxxxxxx/GOOGLE P/UTIB/GOOGL...
# 71                             BY CREDIT INTEREST:xxxxx
# 72                                                  nan
# Name: Desc_masked, Length: 71, dtype: object

# %%
df.tail()
# Out:
#           Date                                        Description  \
# 68  29/06/2025  TO ONL UPI/DR/518086972754/MAHESH S/YESB/PAYTM...
# 69  29/06/2025  TO ONL UPI/DR/518092952923/VIJAYA K/YESB/PAYTM...
# 70  30/06/2025  BY ONL UPI/CR/503670351815/GOOGLE P/UTIB/GOOGL...
# 71  30/06/2025                           BY CREDIT INTEREST:99999
# 72       TOTAL                                                NaN
#
#             Account  Amount                                        Desc_masked
# 68     Expenses:UPI  -88.00  TO ONL UPI/DR/xxxxxxxxxxxx/MAHESH S/YESB/PAYTM...
# 69     Expenses:UPI  -10.00  TO ONL UPI/DR/xxxxxxxxxxxx/VIJAYA K/YESB/PAYTM...
# 70     Expenses:UPI    2.00  BY ONL UPI/CR/xxxxxxxxxxxx/GOOGLE P/UTIB/GOOGL...
# 71  Income:Interest  138.00                           BY CREDIT INTEREST:xxxxx
# 72    Expenses:Misc  370.74                                                nan

# %%
df["Desc_masked"].to_clipboard()
